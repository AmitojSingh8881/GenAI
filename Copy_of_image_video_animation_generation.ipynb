# %% [markdown]
# <a href="https://colab.research.google.com/github/AmitojSingh8881/GenAI/blob/main/Copy_of_image_video_animation_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Title Of The Project : Generative AI for Images and GIFs Built on the Replicate API

# %% [markdown]
# # Project Scope:
# Using the Replicate API to create AI-powered photos and GIFs is the main objective of the project. It comprises responding to user input using GIFs and graphics generated by the API.
#
# As part of this project, we will learn about Replicate's capabilities, design an easy-to-use interface for AI-generated visual content creation and consumption, and include API calls.

# %% [markdown]
# #Name : Amitoj singh
# #ID : 4355516

# %% [markdown]
# #Detailed Description :
# Making AI-powered images and GIFs using the Replicate API is the main focus of this project. The Replicate API takes user input and produces visually beautiful results.
#
# You will learn about several Replicate AI models, set up API calls, and create an interface for simple interaction as part of the implementation. Our goal is to provide a versatile platform that allows users to submit their own instructions, promoting the creation of diverse visual material.

# %% [markdown]
# #Objectve:
# - The Replicate API, which can be used to generate GIFs and photos, is going to be a big part of this project. The usage of AI will allow people to create visually appealing content.
# - An Important objectives include integrating API capabilities, mastering Replicate's models, designing an intuitive interface, and improving the speed of user submissions.
# - The major goal of this project is to develop a comprehensive and versatile tool that can generate different kinds of images and GIFs based on user input.
# - An Building a user-friendly interface for creating diverse content, showcasing model capabilities, speeding up API integration, simplifying user prompt handling, and collaborating with the Replicate API to generate images and GIFs are all part of the project's aims.

# %% [markdown]
# #Outcome:
# - Ideally, our system could generate photos and GIFs using the Replicate API.
# - Users shouldn't have any issues responding to queries, inputting instructions, and visually seeing outcomes when the interface is well-designed.
# - This project shows how adaptable Replicate's AI algorithms are, and it will allow users to make their own GIFs and images.
# - Once the trial period ends, users will have access to Replicate's AI models, which they may use to create their own content. This will demonstrate the system's efficacy and originality.

# %% [markdown]
# #Modification/New Specification Cell:
# - To make sure that the Replicate platform could run models and create content without any problems, the following improvements were made:
# To ensure the proper operation of our models and the generation of our content on the Replicate platform, we used pip to install the replicate library.
#
# - For the purpose of authenticating the communication between the Colab notebook and Replicate, an API token was established.
# Giving a prompt and then using duplicate are all that's needed to make photos.collaborated with an existing trained model.
#
# - The process of creating animated GIFs or films uses a different technique. You may also customize the start and end prompts, as well as the output type (GIF) and ping-pong effect.

# %% [markdown]
# #Justification and importance of Modifications:
# - By using the Replicate API to generate images and GIFs, users are given a powerful and user-friendly tool for developing creative content.
# - We want to address the growing need for AI-powered visual content generation with this initiative, catering to the needs of various users.
# - It simplifies the process of making art, advertising materials, and educational materials.
# - By showcasing the potential of AI to enhance and streamline procedures for developing visual content, it also signifies a step forward in innovative and effective digital production.

# %% [markdown]
# #Criteria Specific:
#
# ##Relevance and application:
# - New algorithmic capabilities are introduced to the area of artificial intelligence (AI) driven visual content generation with the use of the Replicate API to produce pictures and GIFs. The objective of this project is to make unique and unusual photographs faster and easier.
#
# - The advertising industry, educational institutions, and the arts might all benefit from this method as a versatile tool for algorithmic creative creation. This study's potential to spark fresh thinking in the area of visual content production using artificial intelligence (AI) and radically alter the way algorithms function is a major argument in its favor.
#
# ##Innovation:
# - A groundbreaking innovation in the production of creative content is the usage of the Replicate API to create photos and GIFs. The purpose of this project is to use cutting-edge AI algorithms to revolutionize visual storytelling and creative expression.
#
# - The prompt-based development and user-friendly interface are two more revolutionary features that let users create unique graphics. Contributing to the ever-evolving realm of AI-driven creativity, this initiative pushes the boundaries of generative art and fosters fresh ideas.
#
# ##Technical Proficiency:
# - To become technically proficient in this project, you must master the integration of the Replicate API. Included in this is a thorough understanding of how to set up Replicate AI models, optimize API calls, and create prompt-based user interactions.
# - Expertly manage API responses, troubleshoot, and guarantee faultless performance.
# - A To produce GIFs and high-quality photographs whenever the user wants you to, you need to grasp the ins and outs of Replicate's documentation. That's the technical component.

# %%
# @title Install Replicate
# !pip install replicate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# https://replicate.com/andreasjansson/stable-diffusion-animation/api#input-output_format
# List of parameters

# %%
# @title #Get your here: https://replicate.com/signin?next=/account/api-tokens (free for few trials)
API = "r8_5wcNInX7n0uSFw6OZ2YRJXdoJDM98913mgOH0" # @param {type:"string"}
import os

os.environ["REPLICATE_API_TOKEN"] = API #find it here: https://replicate.com/signin?next=/account/api-tokens

# %%
# @title Generate Image
prompt = "Water in Glass"
import replicate

output = replicate.run(
  "stability-ai/stable-diffusion:27b93a2413e7f36cd83da926f3656280b2931564ff050bf9575f1fdf9bcd7478",
  input={"prompt":prompt}
)

output
# Out:
# ['https://replicate.delivery/pbxt/XG6380DRqdbOMRfTSobf2Wd8v4MXCrKJBe1w81VTjyDeczXKB/out-0.png']

# %%
from IPython.display import Image
output_image = output
Image(url=output_image[0])
# Out:
# <img src="https://replicate.delivery/pbxt/XG6380DRqdbOMRfTSobf2Wd8v4MXCrKJBe1w81VTjyDeczXKB/out-0.png"/>

# %%
# @title Video/gif/animation/Generation
import replicate

output = replicate.run(
    "andreasjansson/stable-diffusion-animation:ca1f5e306e5721e19c473e0d094e6603f0456fe759c10715fcd6c1b79242d4a5",
    input={
        "prompt_start": "Water of glass turns to red",
        "prompt_end": "Water of glass turns to transparent again",
        "output_format": "gif",
        "gif_ping_pong": True
    }
)

output
# Out:
# <generator object Prediction.output_iterator at 0x7e776f68ef10>

# %%
# @title generate video
for item in output:
     #https://replicate.com/andreasjansson/stable-diffusion-animation/versions/ca1f5e306e5721e19c473e0d094e6603f0456fe759c10715fcd6c1b79242d4a5/api#output-schema
    print(item)
# Out:
# https://replicate.delivery/pbxt/9Vs9ZxYneSSfeJxZ2i8KsghI9vur4TNeGnrkq01CTGfBanvUC/video.gif

# %%
# @title get the video on colab
gif_url= item[0:len(item)]

# %%
# @title Show the video
import requests
from IPython.display import display, Image
from PIL import Image as PILImage
from io import BytesIO
response = requests.get(gif_url)
if response.status_code == 200:
    # Display the GIF in the notebook
    display(Image(url=gif_url))

    # Save the GIF in the Colab environment
    with open("gif_output.gif", "wb") as f:
        f.write(response.content)

    # Show a saved GIF using PIL
    saved_gif = PILImage.open("gif_output.gif")
    saved_gif.show()
else:
    print("Failed to fetch GIF")
# Out:
# <img src="https://replicate.delivery/pbxt/9Vs9ZxYneSSfeJxZ2i8KsghI9vur4TNeGnrkq01CTGfBanvUC/video.gif"/>

# %% [markdown]
# #Reference:
# - IPython Documentation — IPython 8.18.1 documentation. (n.d.). https://ipython.readthedocs.io/en/stable/
# - Module: display — IPython 3.2.1 documentation. (n.d.). https://ipython.org/ipython-doc/3/api/generated/IPython.display.html
# - Turna.GitHub - turna1/GenAI: Here, we focus on educating and enlightening the community about various Generative AI models through hands-on coding tutorials and informative articles. GitHub. https://github.com/turna1/GenAI

# %% [markdown]
# #ThankYou
